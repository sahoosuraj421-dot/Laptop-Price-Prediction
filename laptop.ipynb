# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("laptop_dataset.csv")

# %% [markdown]
# Data Cleaning

# %%
df.head()
# Out:
#    Company            TypeName  Inches             ScreenResolution  \
# 0     Vero  2 in 1 Convertible   12.19            Full HD 2560x1440
# 1  Samsung  2 in 1 Convertible   16.03             Full HD 1366x768
# 2   Lenovo           Ultrabook   11.81            Full HD 2880x1800
# 3  Toshiba           Ultrabook   16.22            Full HD 3840x2160
# 4   Lenovo            Notebook   15.60  IPS Panel Full HD 1920x1080
#
#                           Cpu   Ram     Memory                       Gpu  \
# 0       Intel Core i5 1.92GHz   4GB  256GB SSD  Nvidia GeForce GTX 1050M
# 1         AMD Ryzen 7 3.51GHz  16GB    1TB SSD      Nvidia GeForce 930MX
# 2       Intel Core i5 2.63GHz   8GB    1TB HDD       AMD FirePro W4190M
# 3       Intel Core i3 2.12GHz   4GB  512GB SSD        Nvidia Quadro M620
# 4  Intel Core i7 8550U 1.8GHz   8GB  256GB SSD         AMD Radeon RX 550
#
#         OpSys  Weight        Price
# 0  Windows 10   3.5kg   27218.8500
# 1       Linux  3.65kg   88026.5100
# 2   Chrome OS  3.13kg   42878.5500
# 3   Chrome OS  3.13kg  197984.7300
# 4  Windows 10   2.1kg   65510.9568

# %%
df.shape
# Out:
# (5000, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           5000 non-null   object
#  1   TypeName          5000 non-null   object
#  2   Inches            5000 non-null   float64
#  3   ScreenResolution  5000 non-null   object
#  4   Cpu               5000 non-null   object
#  5   Ram               5000 non-null   object
#  6   Memory            5000 non-null   object
#  7   Gpu               5000 non-null   object
#  8   OpSys             5000 non-null   object
#  9   Weight            5000 non-null   object
#  10  Price             5000 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 429.8+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop(columns=['Unnamed: 0'], inplace=True)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
df.head()
# Out:
#    Company     TypeName     Inches                      ScreenResolution  \
# 0  Apple_0  Ultrabook_0  19.908181  IPS Panel Retina Display 2560x1600_0
# 1  Apple_1  Ultrabook_1  14.355927                            1440x900_1
# 2     HP_2   Notebook_2  23.021122                   Full HD 1920x1080_2
# 3  Apple_3  Ultrabook_3  23.665414  IPS Panel Retina Display 2880x1800_3
# 4  Apple_4  Ultrabook_4  16.323844  IPS Panel Retina Display 2560x1600_4
#
#                             Cpu     Ram                 Memory  \
# 0        Intel Core i5 2.3GHz_0   8GB_0            128GB SSD_0
# 1        Intel Core i5 1.8GHz_1   8GB_1  128GB Flash Storage_1
# 2  Intel Core i5 7200U 2.5GHz_2   8GB_2            256GB SSD_2
# 3        Intel Core i7 2.7GHz_3  16GB_3            512GB SSD_3
# 4        Intel Core i5 3.1GHz_4   8GB_4            256GB SSD_4
#
#                               Gpu    OpSys    Weight          Price
# 0  Intel Iris Plus Graphics 640_0  macOS_0  1.37kg_0   71382.240368
# 1        Intel HD Graphics 6000_1  macOS_1  1.34kg_1   47897.734800
# 2         Intel HD Graphics 620_2  No OS_2  1.86kg_2   30642.866500
# 3            AMD Radeon Pro 455_3  macOS_3  1.83kg_3  135200.814938
# 4  Intel Iris Plus Graphics 650_4  macOS_4  1.37kg_4   96103.741984

# %%
df["Ram"] = df["Ram"].str.replace("GB","").astype("int32")

# %%
df["Weight"] = df["Weight"].str.replace("kg","").astype("float32")

# %%
df.head()
# Out:
#    Company     TypeName     Inches                      ScreenResolution  \
# 0  Apple_0  Ultrabook_0  19.908181  IPS Panel Retina Display 2560x1600_0
# 1  Apple_1  Ultrabook_1  14.355927                            1440x900_1
# 2     HP_2   Notebook_2  23.021122                   Full HD 1920x1080_2
# 3  Apple_3  Ultrabook_3  23.665414  IPS Panel Retina Display 2880x1800_3
# 4  Apple_4  Ultrabook_4  16.323844  IPS Panel Retina Display 2560x1600_4
#
#                             Cpu  Ram                 Memory  \
# 0        Intel Core i5 2.3GHz_0   80            128GB SSD_0
# 1        Intel Core i5 1.8GHz_1   81  128GB Flash Storage_1
# 2  Intel Core i5 7200U 2.5GHz_2   82            256GB SSD_2
# 3        Intel Core i7 2.7GHz_3  163            512GB SSD_3
# 4        Intel Core i5 3.1GHz_4   84            256GB SSD_4
#
#                               Gpu    OpSys  Weight          Price
# 0  Intel Iris Plus Graphics 640_0  macOS_0   1.370   71382.240368
# 1        Intel HD Graphics 6000_1  macOS_1   1.341   47897.734800
# 2         Intel HD Graphics 620_2  No OS_2   1.862   30642.866500
# 3            AMD Radeon Pro 455_3  macOS_3   1.833  135200.814938
# 4  Intel Iris Plus Graphics 650_4  macOS_4   1.374   96103.741984
